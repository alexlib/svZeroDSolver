# %%
import svzerodsolver
svzerodsolver.solver.set_up_and_run_0d_simulation('../test_cases/pulsatileFlow_R_coronary.json')
svzerodsolver.solver.set_up_and_run_0d_simulation('../test_cases/pulsatileFlow_RL_coronary.json')
svzerodsolver.solver.set_up_and_run_0d_simulation('../test_cases/pulsatileFlow_RLC_coronary.json')
# Out:
# Number of unknowns =  4
# Number of equations =  4
# starting simulation
# 100%|██████████| 30/30 [00:00<00:00, 1578.67it/s]
# Number of unknowns =  5
# Number of equations =  5
# starting simulation
# 100%|██████████| 6000/6000 [00:06<00:00, 955.64it/s]
# 0D simulation completed!
#
# Number of unknowns =  4
# Number of equations =  4
# starting simulation
# 100%|██████████| 30/30 [00:00<00:00, 1579.06it/s]
# Number of unknowns =  5
# Number of equations =  5
# starting simulation
# 100%|██████████| 6000/6000 [00:05<00:00, 1052.04it/s]
# 0D simulation completed!
#
# Number of unknowns =  4
# Number of equations =  4
# starting simulation
# 100%|██████████| 30/30 [00:00<00:00, 1566.83it/s]
# Number of unknowns =  5
# Number of equations =  5
# starting simulation
# 100%|██████████| 6000/6000 [00:05<00:00, 1019.97it/s]
# 0D simulation completed!

# %%
import numpy as np
dataR = np.load('../test_cases/pulsatileFlow_R_coronary_branch_results.npy',allow_pickle=True).item()
dataRL = np.load('../test_cases/pulsatileFlow_RL_coronary_branch_results.npy',allow_pickle=True).item()
dataRLC = np.load('../test_cases/pulsatileFlow_RLC_coronary_branch_results.npy',allow_pickle=True).item()

# %%
import matplotlib.pyplot as plt

fig,ax = plt.subplots(1,3)
ax[0].plot(dataR['time'],dataR['pressure'][0][0])
ax[0].plot(dataR['time'],dataR['pressure'][0][1])
ax[1].plot(dataRL['time'],dataRL['pressure'][0][0])
ax[1].plot(dataRL['time'],dataRL['pressure'][0][1])
ax[2].plot(dataRLC['time'],dataRLC['pressure'][0][0])
ax[2].plot(dataRLC['time'],dataRLC['pressure'][0][1])
