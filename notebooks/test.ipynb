# %%
import svzerodsolver
svzerodsolver.solver.set_up_and_run_0d_simulation('../test_cases/pulsatileFlow_RLC_R.json')
# Out:
# Number of unknowns =  4
# Number of equations =  4
# starting simulation
# 100%|██████████| 30/30 [00:00<00:00, 750.01it/s]
# Number of unknowns =  4
# Number of equations =  4
# starting simulation
# 100%|██████████| 3000/3000 [00:02<00:00, 1010.60it/s]
# 0D simulation completed!

# %%
import numpy as np
dataRLC = np.load('../test_cases/pulsatileFlow_RLC_R_branch_results.npy',allow_pickle=True).item()

# %%
import matplotlib.pyplot as plt

fig,ax = plt.subplots(1,1)
ax.plot(dataRLC['time'],dataRLC['pressure'][0][0])
ax.plot(dataRLC['time'],dataRLC['pressure'][0][1])

# %%
plt.plot(dataRLC['flow'][0][0])
plt.plot(dataRLC['flow'][0][1])
